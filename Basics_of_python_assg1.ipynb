# %% [markdown]
# # **Exercise 1: Prime Numbers**
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
# We know: A prime number is a natural number greater than 1
# and has no positive divisors other than 1 and itself.

num = int(input("Enter a number: "))  # Taking input & converting to integer

if num > 1:
    is_prime = True  # to track if number is prime

    for i in range(2, num):
        if num % i == 0:  # Found a divisor
            is_prime = False
            break

    if is_prime:
        print(num, "is a prime number")
    else:
        print(num, "is not a prime number")

else:
    print(num, "is not a prime number")
# Out:
# Enter a number: 9
# 9 is not a prime number

# %% [markdown]
# # **Exercise 2: Product of Random Numbers**
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message

# %%
import random #we are importing random module because we have to take random numbers here

a=random.randint(1,20) #randint is that it converts it into integer and (1,20) is the range , we can change it also
b=random.randint(1,20)

print(f"the product of numbers: {a}*{b} is") #here 'f' inserts the numbers a and b into the string

try:
  user_answer=int(input("enter the product"))   #here we are using try/except from exceptional handling
except ValueError:
        print("insert only integers")   #ValueError is used because even if the user enter a string or float value , instead of crashing the code , it shows our inputed msg that we used by print statement
else:
  correct_answer=a*b
  if user_answer==correct_answer:
    print("correct")
  else:
    print(f"incorrect and the answer is {correct_answer}") #we will be using "f" for inserting value in the string
# Out:
# the product of numbers: 19*4 is
# enter the product232
# incorrect and the answer is 76

# %% [markdown]
# # **Exercise 3: Squares of Even/Odd Numbers**
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
for num in range(100, 201):
    if num % 2 == 0:  # if number is even
        square = num * num
        print("Number:", num, "Square:", square)
# Out:
# Number: 100 Square: 10000
# Number: 102 Square: 10404
# Number: 104 Square: 10816
# Number: 106 Square: 11236
# Number: 108 Square: 11664
# Number: 110 Square: 12100
# Number: 112 Square: 12544
# Number: 114 Square: 12996
# Number: 116 Square: 13456
# Number: 118 Square: 13924
# Number: 120 Square: 14400
# Number: 122 Square: 14884
# Number: 124 Square: 15376
# Number: 126 Square: 15876
# Number: 128 Square: 16384
# Number: 130 Square: 16900
# Number: 132 Square: 17424
# Number: 134 Square: 17956
# Number: 136 Square: 18496
# Number: 138 Square: 19044
# Number: 140 Square: 19600
# Number: 142 Square: 20164
# Number: 144 Square: 20736
# Number: 146 Square: 21316
# Number: 148 Square: 21904
# Number: 150 Square: 22500
# Number: 152 Square: 23104
# Number: 154 Square: 23716
# Number: 156 Square: 24336
# Number: 158 Square: 24964
# Number: 160 Square: 25600
# Number: 162 Square: 26244
# Number: 164 Square: 26896
# Number: 166 Square: 27556
# Number: 168 Square: 28224
# ...

# %%
for num in range(100, 201):
  if num % 2 != 0:  # if number is odd
      square = num * num
      print("Number:", num, "Square:", square)
# Out:
# Number: 101 Square: 10201
# Number: 103 Square: 10609
# Number: 105 Square: 11025
# Number: 107 Square: 11449
# Number: 109 Square: 11881
# Number: 111 Square: 12321
# Number: 113 Square: 12769
# Number: 115 Square: 13225
# Number: 117 Square: 13689
# Number: 119 Square: 14161
# Number: 121 Square: 14641
# Number: 123 Square: 15129
# Number: 125 Square: 15625
# Number: 127 Square: 16129
# Number: 129 Square: 16641
# Number: 131 Square: 17161
# Number: 133 Square: 17689
# Number: 135 Square: 18225
# Number: 137 Square: 18769
# Number: 139 Square: 19321
# Number: 141 Square: 19881
# Number: 143 Square: 20449
# Number: 145 Square: 21025
# Number: 147 Square: 21609
# Number: 149 Square: 22201
# Number: 151 Square: 22801
# Number: 153 Square: 23409
# Number: 155 Square: 24025
# Number: 157 Square: 24649
# Number: 159 Square: 25281
# Number: 161 Square: 25921
# Number: 163 Square: 26569
# Number: 165 Square: 27225
# Number: 167 Square: 27889
# Number: 169 Square: 28561
# ...

# %% [markdown]
# # Exercise 4:
# ✅ Problem Statement (Question): Hospital Billing System
# A hospital charges its patients based on the following:
# Room charges per day: ₹2,000
# Doctor consultation fee (flat): ₹1,500
# Lab test charges: Based on the number of tests taken. Each test costs ₹300
# Medicine charges: Total cost of medicines provided
# Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
# Write a Python program to calculate the final bill for a patient who:
# Stayed for 4 days
# Had 3 lab tests
# Had medicine charges of ₹2,400

# %%
#summary of the above statement is ,room=2000,consultation fee=1500,lab test=x*300,medicine=2400,if bill>10000,total_bill-10%
room=2000
patient_room=4*room
consultation_fee=1500
lab_test=3*300
medicine=2400
total_bill=patient_room+consultation_fee+lab_test+medicine
print("bill before discount:",total_bill)
if total_bill>10000:
  total_bill=total_bill-total_bill*0.1
  print("bill after discount:",total_bill)
# Out:
# bill before discount: 12800
# bill after discount: 11520.0
